# %%
from google.colab import drive
import requests
import os
import zipfile

# %%
# !df -h .
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# drive           108G   38G   71G  35% /content/drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change directory to the Colab Notebooks folder in Google Drive
# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# Change directory to the Colab Notebooks folder with link to drive of lars
# %cd /content/drive/My Drive/MMDL2024/Colab Notebooks/
# Out:
# /content/drive/.shortcut-targets-by-id/1LQRkg9gduygZjO84k_knGQGpy1qEPTp6/Colab Notebooks

# %%
# Create coco directory if it does not exist
coco_dir = "coco"
if not os.path.exists(coco_dir):
    os.makedirs(coco_dir)
# %cd $coco_dir
# Out:
# /content/drive/.shortcut-targets-by-id/1LQRkg9gduygZjO84k_knGQGpy1qEPTp6/Colab Notebooks/coco

# %%
# Download and extract tallyqa dataset
tallyqa = "https://github.com/manoja328/tallyqa/blob/master/tallyqa.zip?raw=true"
tallyqa_dir = "tallyqa"
tallyqa_zip_dir = "tallyqa.zip"

if not os.path.exists(tallyqa_dir):
    if not os.path.exists(tallyqa_zip_dir):
        # !wget -O $tallyqa_zip_dir $tallyqa
    with zipfile.ZipFile(tallyqa_zip_dir, "r") as zip_ref:
        zip_ref.extractall()
    os.remove(tallyqa_zip_dir)

# Function to download and extract COCO datasets
def download_and_extract(url, zip_dir, extract_dir):
    if not os.path.exists(extract_dir):
        if not os.path.exists(zip_dir):
            # !wget -O $zip_dir $url
        with zipfile.ZipFile(zip_dir, "r") as zip_ref:
            zip_ref.extractall()
        os.remove(zip_dir)

# URLs for COCO datasets
train = "http://images.cocodataset.org/zips/train2014.zip"
train_dir = "train2014"
train_zip_dir = "train2014.zip"

val = "http://images.cocodataset.org/zips/val2014.zip"
val_dir = "val2014"
val_zip_dir = "val2014.zip"

test = "http://images.cocodataset.org/zips/test2015.zip"
test_dir = "test2015"
test_zip_dir = "test2015.zip"

# Download and extract datasets
#download_and_extract(train, train_zip_dir, train_dir)
download_and_extract(val, val_zip_dir, val_dir)
#download_and_extract(test, test_zip_dir, test_dir)

# List the contents of the coco directory
# %ls
# Out:
# --2024-06-12 08:35:37--  https://github.com/manoja328/tallyqa/blob/master/tallyqa.zip?raw=true
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/manoja328/TallyQA_dataset/blob/master/tallyqa.zip?raw=true [following]
# --2024-06-12 08:35:37--  https://github.com/manoja328/TallyQA_dataset/blob/master/tallyqa.zip?raw=true
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/manoja328/TallyQA_dataset/raw/master/tallyqa.zip [following]
# --2024-06-12 08:35:37--  https://github.com/manoja328/TallyQA_dataset/raw/master/tallyqa.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/manoja328/TallyQA_dataset/master/tallyqa.zip [following]
# ...

# %%
def count_files_in_directories(path):
    directories = [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
    file_counts = {directory: len(os.listdir(os.path.join(path, directory))) for directory in directories}
    return file_counts

def print_file_counts(directories):
    for directory in directories:
        if os.path.exists(directory):
            file_count = len(os.listdir(directory))
            print(f"Number of files in {directory}: {file_count}")
        else:
            print(f"Directory {directory} does not exist")

# %%
from pathlib import Path

train_dir = "train2014"
val_dir = "val2014"
test_dir = "test2015"
coco_dir = "coco"

# List of directories to check
directories_to_check = [f"{coco_dir}/{train_dir}", f"{coco_dir}/{val_dir}", f"{coco_dir}/{test_dir}"]

print(len(list(Path(f"{coco_dir}/{train_dir}").iterdir())))
print(len(list(Path(f"{coco_dir}/{val_dir}").iterdir())))
print(len(list(Path(f"{coco_dir}/{test_dir}").iterdir())))
# Print the number of files in each directory
#print_file_counts(directories_to_check)
# Out:
# 82783
# 15233
# 2353
